# %%
x = 1

# %%
# guardar el modelo entrenadoimport joblib
import joblib
import pandas as pd
# joblib.dump(modelo, 'modelo_abandono_clientes.pkl')
# cargar el modelo entrenado
modelo_cargado = joblib.load('modelo_abandono_clientes.pkl')
# # usando el modelo cargado para predecir si un cliente con ingreso de $4000 y 4 visitas comprará

# %%
nuevo_cliente = pd.DataFrame({
    "ingreso": [4000],
    "visitas": [4]
})
prediccion_nuevo = modelo_cargado.predict(nuevo_cliente)
print(f"Predicción para nuevo cliente (ingreso=$4000, visitas=4): {prediccion_nuevo[0]} (1=compra, 0=no compra)")
# Out:
# Predicción para nuevo cliente (ingreso=$4000, visitas=4): 1 (1=compra, 0=no compra)
